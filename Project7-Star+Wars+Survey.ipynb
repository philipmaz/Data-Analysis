# %%
import pandas as pd

star_wars=pd.read_csv('star_wars.csv',encoding="ISO-8859-1")

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
star_wars=star_wars[star_wars['RespondentID'].notnull()]

# %%
yes_no={'Yes':True,'No':False}
star_wars['Have you seen any of the 6 films in the Star Wars franchise?']=star_wars['Have you seen any of the 6 films in the Star Wars franchise?'].map(yes_no)
star_wars['Have you seen any of the 6 films in the Star Wars franchise?'].head()
# Out:
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: bool

# %%
star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?']=star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?'].map(yes_no)
star_wars['Do you consider yourself to be a fan of the Star Wars film franchise?'].head()
# Out:
# 1     True
# 2      NaN
# 3    False
# 4     True
# 5     True
# Name: Do you consider yourself to be a fan of the Star Wars film franchise?, dtype: object

# %%
star_wars.columns[3:9]
# Out:
# Index(['Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
column_names={'Which of the following Star Wars films have you seen? Please select all that apply.':'seen_1','Unnamed: 4':'seen_2','Unnamed: 5':'seen_3', 'Unnamed: 6':'seen_4', 'Unnamed: 7':'seen_5', 'Unnamed: 8':'seen_6'}


star_wars=star_wars.rename(columns=column_names)
star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#                                      seen_1  \
# 1  Star Wars: Episode I  The Phantom Menace
# 2                                       NaN
# 3  Star Wars: Episode I  The Phantom Menace
# ...

# %%
import numpy as np
movie_mapping = {
    "Star Wars: Episode I  The Phantom Menace": True,
    np.nan: False,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True
}

for col in star_wars.columns[3:9]:
    star_wars[col]=star_wars[col].map(movie_mapping)

star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# 30    3.292377e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# %%
rename_dict={'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.':'ranking_1',
       'Unnamed: 10':'ranking_2', 'Unnamed: 11':'ranking_3', 'Unnamed: 12':'ranking_4', 'Unnamed: 13':'ranking_5',
       'Unnamed: 14':'ranking_6'}

star_wars=star_wars.rename(columns=rename_dict)

# %%
star_wars[star_wars.columns[9:15]].mean()
# Out:
# ranking_1    3.732934
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    3.047847
# dtype: float64

# %%
# %matplotlib inline

star_wars[star_wars.columns[9:15]].mean().plot.bar()

# %% [markdown]
# It looks like the "original" movies are rated much more highly than the newer ones.

# %%
star_wars[star_wars.columns[3:9]].sum()
# Out:
# seen_1    673
# seen_2    571
# seen_3    550
# seen_4    607
# seen_5    758
# seen_6    738
# dtype: int64

# %%
star_wars[star_wars.columns[3:9]].sum().plot.bar()

# %% [markdown]
# # View counts
# It appears that the original movies were seen by more respondents than the newer movies. This reinforces what we saw in the rankings, where the earlier movies seem to be more popular.

# %%
males = star_wars[star_wars["Gender"] == "Male"]
females = star_wars[star_wars["Gender"] == "Female"]

# %%
males[males.columns[3:9]].sum().plot.bar()

# %%
females[females.columns[3:9]].sum().plot.bar()

# %%
males[males.columns[9:15]].mean().plot.bar()

# %%
females[females.columns[3:9]].sum().plot.bar()

# %% [markdown]
# # Male/Female differences in favorite Star Wars movie and most seen movie
# Interestingly, more males watches episodes 1-3, but males liked them far less than females did.

# %%
star_wars['Education'].value_counts()
# Out:
# Some college or Associate degree    328
# Bachelor degree                     321
# Graduate degree                     275
# High school degree                  105
# Less than high school degree          7
# Name: Education, dtype: int64

# %%
star_degree=star_wars[(star_wars['Education']=='Some college or Associate degree') |
                     (star_wars['Education']=='Bachelor degree') | (star_wars['Education']=='Graduate degree')]

star_degree[star_degree.columns[9:15]].mean().plot.bar()

# %%
star_degree[star_degree.columns[3:9]].sum().plot.bar()

# %%
star_school=star_wars[(star_wars['Education']=='High school degree') |
                     (star_wars['Education']=='Less than high school degree')]

star_school[star_school.columns[9:15]].mean().plot.bar()

# %%
star_school[star_school.columns[3:9]].sum().plot.bar()

# %% [markdown]
# # Education level differences
# There is no major difference between people with higher degrees and without. Looks like star wars part 5 is the most frequently seen and ranked the highest of all.

# %%
star_wars['Age'].value_counts()
# Out:
# 45-60    291
# > 60     269
# 30-44    268
# 18-29    218
# Name: Age, dtype: int64

# %%
between45and60=star_wars[star_wars['Age']=='45-60']
over60=star_wars[star_wars['Age']=='> 60']
between30and44=star_wars[star_wars['Age']=='30-44']
between18and29=star_wars[star_wars['Age']=='18-29']

# %%
between45and60[between45and60.columns[9:15]].mean().plot.bar(title='45-60')

# %%
over60[over60.columns[9:15]].mean().plot.bar(title='> 60')

# %%
between30and44[between30and44.columns[9:15]].mean().plot.bar(title='30-44')

# %%
between18and29[between18and29.columns[9:15]].mean().plot.bar(title='18-29')

# %% [markdown]
# # Age group differences
# Part 5 remains as the best ranked regardless age group, however it looks like the difference in ranking becomes more moderate in younger age groups.

# %%
star_wars['Which character shot first?'].value_counts()
# Out:
# Han                                 325
# I don't understand this question    306
# Greedo                              197
# Name: Which character shot first?, dtype: int64

# %% [markdown]
# Nearly half of surveyed people didn't understand this question. Most of the rest who gave answer put 'Han Solo' as the character who has been shot first.

# %%
wars_trek=star_wars[['Do you consider yourself to be a fan of the Star Wars film franchise?','Do you consider yourself to be a fan of the Star Trek franchise?']]
wars_trek
# Out:
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                  True
# 2                                                   NaN
# 3                                                 False
# 4                                                  True
# 5                                                  True
# 6                                                  True
# 7                                                  True
# 8                                                  True
# 9                                                  True
# 10                                                False
# 11                                                  NaN
# 12                                                  NaN
# 13                                                False
# 14                                                 True
# 15                                                 True
# ...

# %%
dict={'Yes':True,'No':False,np.NaN:False}

wars_trek['Do you consider yourself to be a fan of the Star Trek franchise?']=wars_trek['Do you consider yourself to be a fan of the Star Trek franchise?'].map(dict)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
wars_trek['Do you consider yourself to be a fan of the Star Wars film franchise?']=wars_trek['Do you consider yourself to be a fan of the Star Wars film franchise?'].replace(np.NaN,False)
wars_trek
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#       Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                  True
# 2                                                 False
# 3                                                 False
# 4                                                  True
# 5                                                  True
# 6                                                  True
# 7                                                  True
# 8                                                  True
# 9                                                  True
# ...

# %%
wars_trek.corr().plot.bar(legend=False)

# %% [markdown]
# # Star Wars and Star Trek correlations
# It looks like around 60% of people who declare themselfes as fans are also Star Trek fans and the other way around.
